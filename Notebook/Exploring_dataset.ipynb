# %% [markdown]
# # **Huge Exploratory Data Analysis: Country Statistics 🌍🔍**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Read dataset
input_df = pd.read_csv('./../Dataset/world_dataset.csv')
input_df.head()
# Out:
#        Country Density\n(P/Km2) Abbreviation Agricultural Land( %)  \
# 0  Afghanistan               60           AF                58.10%
# 1      Albania              105           AL                43.10%
# 2      Algeria               18           DZ                17.40%
# 3      Andorra              164           AD                40.00%
# 4       Angola               26           AO                47.50%
#
#   Land Area(Km2) Armed Forces size  Birth Rate  Calling Code  \
# 0        652,230           323,000       32.49          93.0
# 1         28,748             9,000       11.78         355.0
# 2      2,381,741           317,000       24.28         213.0
# 3            468               NaN        7.20         376.0
# 4      1,246,700           117,000       40.73         244.0
#
#   Capital/Major City Co2-Emissions  ... Out of pocket health expenditure  \
# 0              Kabul         8,672  ...                           78.40%
# 1             Tirana         4,536  ...                           56.90%
# 2            Algiers       150,006  ...                           28.10%
# 3   Andorra la Vella           469  ...                           36.40%
# 4             Luanda        34,693  ...                           33.40%
#
#   Physicians per thousand  Population  \
# 0                    0.28  38,041,754
# 1                    1.20   2,854,191
# 2                    1.72  43,053,054
# 3                    3.33      77,142
# 4                    0.21  31,825,295
#
#    Population: Labor force participation (%) Tax revenue (%) Total tax rate  \
# 0                                     48.90%           9.30%         71.40%
# 1                                     55.70%          18.60%         36.60%
# 2                                     41.20%          37.20%         66.10%
# 3                                        NaN             NaN            NaN
# 4                                     77.50%           9.20%         49.10%
#
#   Unemployment rate Urban_population   Latitude  Longitude
# 0            11.12%        9,797,273  33.939110  67.709953
# 1            12.33%        1,747,593  41.153332  20.168331
# 2            11.70%       31,510,100  28.033886   1.659626
# 3               NaN           67,873  42.506285   1.521801
# 4             6.89%       21,061,025 -11.202692  17.873887
#
# [5 rows x 35 columns]

# %%
# Get length of dataset
print(f'Length of input dataset: {len(input_df)}\n')

# Get all columns name
columns_name = input_df.columns
columns_name
# Out:
# Length of input dataset: 195
# Index(['Country', 'Density\n(P/Km2)', 'Abbreviation', 'Agricultural Land( %)',
#        'Land Area(Km2)', 'Armed Forces size', 'Birth Rate', 'Calling Code',
#        'Capital/Major City', 'Co2-Emissions', 'CPI', 'CPI Change (%)',
#        'Currency-Code', 'Fertility Rate', 'Forested Area (%)',
#        'Gasoline Price', 'GDP', 'Gross primary education enrollment (%)',
#        'Gross tertiary education enrollment (%)', 'Infant mortality',
#        'Largest city', 'Life expectancy', 'Maternal mortality ratio',
#        'Minimum wage', 'Official language', 'Out of pocket health expenditure',
#        'Physicians per thousand', 'Population',
#        'Population: Labor force participation (%)', 'Tax revenue (%)',
#        'Total tax rate', 'Unemployment rate', 'Urban_population', 'Latitude',
#        'Longitude'],
#       dtype='object')

# %%
input_df[input_df.isnull().any(axis=1)]
# Out:
#                  Country Density\n(P/Km2) Abbreviation Agricultural Land( %)  \
# 3                Andorra              164           AD                40.00%
# 5    Antigua and Barbuda              223           AG                20.50%
# 9                Austria              109           AT                32.40%
# 11           The Bahamas               39           BS                 1.40%
# 12               Bahrain            2,239           BH                11.10%
# ..                   ...              ...          ...                   ...
# 188           Uzbekistan               79           UZ                62.90%
# 189              Vanuatu               25           VU                15.30%
# 190            Venezuela               32           VE                24.50%
# 192                Yemen               56           YE                44.60%
# 194             Zimbabwe               38           ZW                41.90%
#
#     Land Area(Km2) Armed Forces size  Birth Rate  Calling Code  \
# 3              468               NaN        7.20         376.0
# 5              443                 0       15.33           1.0
# 9           83,871            21,000        9.70          43.0
# 11          13,880             1,000       13.97           1.0
# 12             765            19,000       13.99         973.0
# ..             ...               ...         ...           ...
# 188        447,400            68,000       23.30         998.0
# 189         12,189               NaN       29.60         678.0
# 190        912,050           343,000       17.88          58.0
# 192        527,968            40,000       30.45         967.0
# 194        390,757            51,000       30.68         263.0
#
#          Capital/Major City Co2-Emissions  ...  \
# 3          Andorra la Vella           469  ...
# 5    St. John's, Saint John           557  ...
# 9                    Vienna        61,448  ...
# 11          Nassau, Bahamas         1,786  ...
# 12                   Manama        31,694  ...
# ..                      ...           ...  ...
# 188                Tashkent        91,811  ...
# 189               Port Vila           147  ...
# 190                 Caracas       164,175  ...
# 192                   Sanaa        10,609  ...
# 194                  Harare        10,983  ...
#
#     Out of pocket health expenditure Physicians per thousand  Population  \
# 3                             36.40%                    3.33      77,142
# 5                             24.30%                    2.76      97,118
# 9                             17.90%                    5.17   8,877,067
# 11                            27.80%                    1.94     389,482
# 12                            25.10%                    0.93   1,501,635
# ..                               ...                     ...         ...
# 188                           42.70%                    2.37  33,580,650
# 189                            8.90%                    0.17     299,882
# 190                           45.80%                    1.92  28,515,829
# 192                           81.00%                    0.31  29,161,922
# 194                           25.80%                    0.21  14,645,468
#
#      Population: Labor force participation (%) Tax revenue (%) Total tax rate  \
# 3                                          NaN             NaN            NaN
# 5                                          NaN          16.50%         43.00%
# 9                                       60.70%          25.40%         51.40%
# 11                                      74.60%          14.80%         33.80%
# 12                                      73.40%           4.20%         13.80%
# ..                                         ...             ...            ...
# 188                                     65.10%          14.80%         31.60%
# 189                                     69.90%          17.80%          8.50%
# 190                                     59.70%             NaN         73.30%
# 192                                     38.00%             NaN         26.60%
# 194                                     83.10%          20.70%         31.60%
#
#     Unemployment rate Urban_population   Latitude   Longitude
# 3                 NaN           67,873  42.506285    1.521801
# 5                 NaN           23,800  17.060816  -61.796428
# 9               4.67%        5,194,416  47.516231   14.550072
# 11             10.36%          323,784  25.034280  -77.396280
# 12              0.71%        1,467,109  26.066700   50.557700
# ..                ...              ...        ...         ...
# 188             5.92%       16,935,729  41.377491   64.585262
# 189             4.39%           76,152 -15.376706  166.959158
# 190             8.80%       25,162,368   6.423750  -66.589730
# 192            12.91%       10,869,523  15.552727   48.516388
# 194             4.95%        4,717,305 -19.015438   29.154857
#
# [85 rows x 35 columns]

# %%
# Check duplicated data and drop
input_df.duplicated().sum()
cleaned_duplicated = input_df.drop_duplicates()

# Convert to pandas NaN to handle error
cleaned_df = cleaned_duplicated.replace('nan', pd.NA)
print(f'Dataset length: {len(cleaned_df)}')
# Out:
# Dataset length: 195

# %% [markdown]
# # **Comparative Analysis of GDP, Life Expectancy, and Unemployment Rate :**

# %%
# Select relevant columns for comparative analysis
columns = ['Country', 'GDP', 'Life expectancy', 'Unemployment rate']
comparative_data = cleaned_df[columns]
#comparative_data.to_csv('../Report_materials/../Report_materials/comparative_data.csv', index=False)
comparative_data
# Out:
#          Country                GDP  Life expectancy Unemployment rate
# 0    Afghanistan   $19,101,353,833              64.5            11.12%
# 1        Albania   $15,278,077,447              78.5            12.33%
# 2        Algeria  $169,988,236,398              76.7            11.70%
# 3        Andorra    $3,154,057,987               NaN               NaN
# 4         Angola   $94,635,415,870              60.8             6.89%
# ..           ...                ...              ...               ...
# 190    Venezuela  $482,359,318,768              72.1             8.80%
# 191      Vietnam  $261,921,244,843              75.3             2.01%
# 192        Yemen   $26,914,402,224              66.1            12.91%
# 193       Zambia   $23,064,722,446              63.5            11.43%
# 194     Zimbabwe   $21,440,758,800              61.2             4.95%
#
# [195 rows x 4 columns]

# %%
# Calculate descriptive statistics for each column
statistics = comparative_data.describe()
#statistics.to_csv('../Report_materials/statistics.csv', index=False)
statistics
# Out:
#        Life expectancy
# count       187.000000
# mean         72.279679
# std           7.483661
# min          52.800000
# 25%          67.000000
# 50%          73.200000
# 75%          77.500000
# max          85.400000

# %%
# Compare countries based on GDP
gdp_ranking = comparative_data.sort_values('GDP', ascending=False)
#gdp_ranking.to_csv('../Report_materials/gdp_ranking.csv', index=False)
gdp_ranking
# Out:
#                             Country                  GDP  Life expectancy  \
# 57                         Ethiopia     $96,107,662,398              66.2
# 88                            Kenya     $95,503,088,538              66.3
# 4                            Angola     $94,635,415,870              60.8
# 189                         Vanuatu        $917,058,851              70.3
# 122                     Netherlands    $909,070,395,161              81.8
# ..                              ...                  ...              ...
# 38                          Comoros      $1,185,728,677              64.1
# 78                        Indonesia  $1,119,190,780,753              71.5
# 145           Saint Kitts and Nevis      $1,050,992,593              71.3
# 73                     Vatican City                  NaN              NaN
# 133  Palestinian National Authority                  NaN              NaN
#
#     Unemployment rate
# 57              2.08%
# 88              2.64%
# 4               6.89%
# 189             4.39%
# 122             3.20%
# ..                ...
# 38              4.34%
# 78              4.69%
# 145               NaN
# 73                NaN
# 133               NaN
#
# [195 rows x 4 columns]

# %%
# Compare countries based on life expectancy
life_expectancy_ranking = comparative_data.sort_values('Life expectancy', ascending=False)
#life_expectancy_ranking.to_csv('../Report_materials/life_expectancy_ranking.csv', index=False)
life_expectancy_ranking
# Out:
#                             Country                  GDP  Life expectancy  \
# 149                      San Marino      $1,637,931,034              85.4
# 85                            Japan  $5,081,769,542,380              84.2
# 169                     Switzerland    $703,082,435,360              83.6
# 164                           Spain  $1,394,116,310,769              83.3
# 156                       Singapore    $372,062,527,489              83.1
# ..                              ...                  ...              ...
# 113                          Monaco      $7,184,844,193               NaN
# 120                           Nauru        $133,000,000               NaN
# 128                 North Macedonia     $10,220,781,069               NaN
# 133  Palestinian National Authority                  NaN              NaN
# 181                          Tuvalu         $47,271,463               NaN
#
#     Unemployment rate
# 149               NaN
# 85              2.29%
# 169             4.58%
# 164            13.96%
# 156             4.11%
# ..                ...
# 113               NaN
# 120               NaN
# 128               NaN
# 133               NaN
# 181               NaN
#
# [195 rows x 4 columns]

# %%
top30_life_expectancy = life_expectancy_ranking.head(30)
plt.figure(figsize=(15, 6))  # Set the figure size
top30_life_expectancy.plot(x='Country', y='Life expectancy', kind='bar')
plt.title('Top 30 Countries - Life Expectancy')
plt.xlabel('Country')
plt.ylabel('Life Expectancy')
plt.xticks(rotation=90)
plt.tight_layout()  # Adjust spacing
plt.savefig('../Report_materials/top30_life_expectancy_graph.png')

# %%
# Compare countries based on unemployment rate
unemployment_ranking = comparative_data.sort_values('Unemployment rate')
unemployment_ranking.to_csv('../Report_materials/unemployment_ranking.csv', index=False)
unemployment_ranking
# Out:
#                             Country                GDP  Life expectancy  \
# 141                           Qatar  $183,466,208,791              80.1
# 125                           Niger   $12,928,145,120              62.0
# 159                 Solomon Islands    $1,425,074,226              72.8
# 92                             Laos   $18,173,839,128              67.6
# 30                         Cambodia   $27,089,389,787              69.6
# ..                              ...                ...              ...
# 133  Palestinian National Authority                NaN              NaN
# 145           Saint Kitts and Nevis    $1,050,992,593              71.3
# 149                      San Marino    $1,637,931,034              85.4
# 154                      Seychelles    $1,698,843,063              72.8
# 181                          Tuvalu       $47,271,463               NaN
#
#     Unemployment rate
# 141             0.09%
# 125             0.47%
# 159             0.58%
# 92              0.63%
# 30              0.68%
# ..                ...
# 133               NaN
# 145               NaN
# 149               NaN
# 154               NaN
# 181               NaN
#
# [195 rows x 4 columns]

# %% [markdown]
# # **Demographic Analysis of Top 20 Countries :**

# %%
# Select relevant columns for demographic analysis
columns = ['Country', 'Birth Rate', 'Infant mortality', 'Urban_population']
demographic_data = cleaned_df[columns]

# %%
# Make a copy of the DataFrame to avoid the warning
demographic_data = demographic_data.copy()

# %%
# Sort data by Birth Rate in descending order
demographic_data.sort_values('Birth Rate', ascending=False, inplace=True)

# %%
# Take top 20 entries
demographic_data_top20 = demographic_data.head(20)

# %%
# Analyze birth rate
birth_rate_statistics = demographic_data_top20['Birth Rate'].describe()
birth_rate_statistics.to_csv('../Report_materials/birth_rate_statistics.csv')

# %%
birth_rate_statistics
# Out:
# count    20.000000
# mean     38.479000
# std       2.918397
# min      35.130000
# 25%      36.212500
# 50%      37.920000
# 75%      40.842500
# max      46.080000
# Name: Birth Rate, dtype: float64

# %%
# Generate birth rate graph
demographic_data_top20.plot(x='Country', y='Birth Rate', kind='bar')
plt.title('Top 20 Countries - Birth Rate')
plt.xlabel('Country')
plt.ylabel('Birth Rate')
plt.xticks(rotation=90)
plt.savefig('../Report_materials/birth_rate_graph.png')

# %%
# Analyze infant mortality rate
infant_mortality_statistics = demographic_data_top20['Infant mortality'].describe()
infant_mortality_statistics.to_csv('../Report_materials/infant_mortality_statistics.csv')

# %%
infant_mortality_statistics
# Out:
# count    20.000000
# mean     56.110000
# std      14.355923
# min      33.800000
# 25%      46.250000
# 50%      54.000000
# 75%      65.725000
# max      84.500000
# Name: Infant mortality, dtype: float64

# %%
# Generate infant mortality rate graph
demographic_data_top20.plot(x='Country', y='Infant mortality', kind='bar')
plt.title('Top 20 Countries - Infant Mortality Rate')
plt.xlabel('Country')
plt.ylabel('Infant Mortality Rate')
plt.xticks(rotation=90)
plt.savefig('../Report_materials/infant_mortality_graph.png')

# %%
# Analyze urban/rural distribution
urban_rural_distribution = demographic_data_top20.groupby('Urban_population').size()
urban_rural_distribution.to_csv('../Report_materials/urban_rural_distribution.csv')

# %%
urban_rural_distribution
# Out:
# Urban_population
# 1,453,958      1
# 1,541,177      1
# 1,982,064      1
# 10,784,516     1
# 102,806,948    1
# 11,092,106     1
# 13,176,900     1
# 14,741,256     1
# 20,011,885     1
# 21,061,025     1
# 3,712,273      1
# 3,850,231      1
# 39,095,679     1
# 4,661,505      1
# 5,648,149      1
# 6,092,349      1
# 7,034,861      1
# 7,871,713      1
# 8,479,688      1
# 840,922        1
# dtype: int64

# %%
# Generate urban/rural distribution graph
urban_rural_distribution.plot(kind='pie', autopct='%1.1f%%')
plt.title('Top 20 Countries - Urban vs Rural Population Distribution')
plt.ylabel('')
plt.savefig('../Report_materials/urban_rural_distribution_graph.png')

# %% [markdown]
# # **Environmental Analysis of CO2 Emissions, Forested Area, and Agricultural Land :**

# %%
# Select relevant columns for environmental analysis
columns = ['Country', 'Co2-Emissions', 'Forested Area (%)', 'Agricultural Land( %)']
environmental_data = cleaned_df[columns]

# %%
# Analyze CO2 emissions
co2_emissions_statistics = environmental_data['Co2-Emissions'].describe()
co2_emissions_statistics.to_csv('../Report_materials/co2_emissions_statistics.csv')

# %%
co2_emissions_statistics
# Out:
# count     188
# unique    184
# top       143
# freq        2
# Name: Co2-Emissions, dtype: object

# %%
# Analyze forested area
forested_area_statistics = environmental_data['Forested Area (%)'].describe()
forested_area_statistics.to_csv('../Report_materials/forested_area_statistics.csv')

# %%
forested_area_statistics
# Out:
# count        188
# unique       161
# top       43.10%
# freq           3
# Name: Forested Area (%), dtype: object

# %%
# Analyze agricultural land
agricultural_land_statistics = environmental_data['Agricultural Land( %)'].describe()
agricultural_land_statistics.to_csv('../Report_materials/agricultural_land_statistics.csv')

# %%
agricultural_land_statistics
# Out:
# count        188
# unique       168
# top       17.40%
# freq           3
# Name: Agricultural Land( %), dtype: object

# %% [markdown]
# # **Health Analysis of Life Expectancy, Infant Mortality, Maternal Mortality, and Health Expenditure :**

# %%
# Select relevant columns for health analysis
columns = ['Country', 'Life expectancy', 'Infant mortality', 'Maternal mortality ratio', 'Out of pocket health expenditure']
health_data = cleaned_df[columns]

# %%
# Analyze life expectancy
life_expectancy_statistics = health_data['Life expectancy'].describe()
life_expectancy_statistics.to_csv('../Report_materials/life_expectancy_statistics.csv')

# %%
life_expectancy_statistics
# Out:
# count    187.000000
# mean      72.279679
# std        7.483661
# min       52.800000
# 25%       67.000000
# 50%       73.200000
# 75%       77.500000
# max       85.400000
# Name: Life expectancy, dtype: float64

# %%
# Life expectancy graph
top30_life_expectancy = health_data.nlargest(30, 'Life expectancy')
top30_life_expectancy.plot(x='Country', y='Life expectancy', kind='bar')
plt.title('Top 30 Countries - Life Expectancy')
plt.xlabel('Country')
plt.ylabel('Life Expectancy')
plt.xticks(rotation=90)
plt.savefig('../Report_materials/life_expectancy_graph.png')

# %%
# Analyze infant mortality rate
infant_mortality_statistics = health_data['Infant mortality'].describe()
infant_mortality_statistics.to_csv('../Report_materials/infant_mortality_statistics.csv')

# %%
infant_mortality_statistics
# Out:
# count    189.000000
# mean      21.332804
# std       19.548058
# min        1.400000
# 25%        6.000000
# 50%       14.000000
# 75%       32.700000
# max       84.500000
# Name: Infant mortality, dtype: float64

# %%
# Infant mortality rate graph
top30_infant_mortality = health_data.nsmallest(30, 'Infant mortality')
top30_infant_mortality.plot(x='Country', y='Infant mortality', kind='bar')
plt.title('Top 30 Countries - Infant Mortality Rate')
plt.xlabel('Country')
plt.ylabel('Infant Mortality Rate')
plt.xticks(rotation=90)
plt.savefig('../Report_materials/infant_mortality_graph.png')

# %%
# Analyze maternal mortality ratio
maternal_mortality_statistics = health_data['Maternal mortality ratio'].describe()
maternal_mortality_statistics.to_csv('../Report_materials/maternal_mortality_statistics.csv')

# %%
maternal_mortality_statistics
# Out:
# count     181.000000
# mean      160.392265
# std       233.502024
# min         2.000000
# 25%        13.000000
# 50%        53.000000
# 75%       186.000000
# max      1150.000000
# Name: Maternal mortality ratio, dtype: float64

# %%
# Maternal mortality ratio graph
top30_maternal_mortality = health_data.nlargest(30, 'Maternal mortality ratio')
top30_maternal_mortality.plot(x='Country', y='Maternal mortality ratio', kind='bar')
plt.title('Top 30 Countries - Maternal Mortality Ratio')
plt.xlabel('Country')
plt.ylabel('Maternal Mortality Ratio')
plt.xticks(rotation=90)
plt.savefig('../Report_materials/maternal_mortality_graph.png')

# %%
# Analyze out-of-pocket health expenditure
out_of_pocket_expenditure_statistics = health_data['Out of pocket health expenditure'].describe()
out_of_pocket_expenditure_statistics.to_csv('../Report_materials/out_of_pocket_expenditure_statistics.csv')

# %%
out_of_pocket_expenditure_statistics
# Out:
# count        188
# unique       160
# top       40.50%
# freq           3
# Name: Out of pocket health expenditure, dtype: object

# %% [markdown]
# # **Educational Analysis of Primary and Tertiary School Enrollment :**

# %%
# Select relevant columns for educational analysis
columns = ['Country', 'Gross primary education enrollment (%)', 'Gross tertiary education enrollment (%)']
educational_data = cleaned_df[columns]

# %%
# Analyze primary school enrollment rate
primary_enrollment_statistics = educational_data['Gross primary education enrollment (%)'].describe()
primary_enrollment_statistics.to_csv('../Report_materials/primary_enrollment_statistics.csv')

# %%
primary_enrollment_statistics
# Out:
# count         188
# unique        141
# top       104.00%
# freq            4
# Name: Gross primary education enrollment (%), dtype: object

# %%
# Analyze tertiary school enrollment rate
tertiary_enrollment_statistics = educational_data['Gross tertiary education enrollment (%)'].describe()
tertiary_enrollment_statistics.to_csv('../Report_materials/tertiary_enrollment_statistics.csv')

# %%
tertiary_enrollment_statistics
# Out:
# count        183
# unique       171
# top       10.20%
# freq           3
# Name: Gross tertiary education enrollment (%), dtype: object

# %% [markdown]
# # **Labor Market Analysis :**
# This code performs an analysis of the labor market using relevant columns from the dataset. It focuses on the labor force participation rate, unemployment rate, and armed forces size in different countries.

# %%
# Select relevant columns for labor market analysis
columns = ['Country', 'Population: Labor force participation (%)', 'Unemployment rate', 'Armed Forces size']
labor_market_data = cleaned_df[columns]

# %%
# Analyze labor force participation rate
labor_force_participation_statistics = labor_market_data['Population: Labor force participation (%)'].describe()
labor_force_participation_statistics.to_csv('../Report_materials/labor_force_participation_statistics.csv')

# %%
labor_force_participation_statistics
# Out:
# count        176
# unique       145
# top       68.80%
# freq           3
# Name: Population: Labor force participation (%), dtype: object

# %%
# Analyze unemployment rate
unemployment_rate_statistics = labor_market_data['Unemployment rate'].describe()
unemployment_rate_statistics.to_csv('../Report_materials/unemployment_rate_statistics.csv')

# %%
unemployment_rate_statistics
# Out:
# count       176
# unique      164
# top       4.59%
# freq          3
# Name: Unemployment rate, dtype: object

# %%
# Analyze armed forces size
armed_forces_size_statistics = labor_market_data['Armed Forces size'].describe()
armed_forces_size_statistics.to_csv('../Report_materials/armed_forces_size_statistics.csv')

# %%
armed_forces_size_statistics
# Out:
# count       171
# unique      105
# top       2,000
# freq          7
# Name: Armed Forces size, dtype: object

# %% [markdown]
# # **Tax Analysis :**
# This code performs an analysis of tax-related data using relevant columns from the dataset. It focuses on the total tax rate and tax revenue percentage in different countries.

# %%
# Select relevant columns for tax analysis
columns = ['Country', 'Total tax rate', 'Tax revenue (%)']
tax_data = cleaned_df[columns]

# %%
# Analyze total tax rate
total_tax_rate_statistics = tax_data['Total tax rate'].describe()
total_tax_rate_statistics.to_csv('../Report_materials/total_tax_rate_statistics.csv')

# %%
total_tax_rate_statistics
# Out:
# count        183
# unique       156
# top       36.60%
# freq           4
# Name: Total tax rate, dtype: object

# %%
# Analyze tax revenue
tax_revenue_statistics = tax_data['Tax revenue (%)'].describe()
tax_revenue_statistics.to_csv('../Report_materials/tax_revenue_statistics.csv')

# %%
tax_revenue_statistics
# Out:
# count        169
# unique       119
# top       19.50%
# freq           4
# Name: Tax revenue (%), dtype: object

# %% [markdown]
# # **Urbanization Analysis :**
# This code performs an analysis of urbanization using relevant columns from the dataset. It focuses on the urban population distribution and the characteristics of the largest cities in different countries. The code calculates the distribution of urban population and descriptive statistics for the largest cities.

# %%
# Select relevant columns for urbanization analysis
columns = ['Country', 'Urban_population', 'Largest city']
urbanization_data = cleaned_df[columns]

# %%
# Analyze urban population distribution
urban_population_distribution = urbanization_data.groupby('Urban_population').size()
urban_population_distribution.to_csv('../Report_materials/urban_population_distribution.csv')

# %%
urban_population_distribution
# Out:
# Urban_population
# 1,135,502    1
# 1,144,654    1
# 1,149,670    1
# 1,162,834    1
# 1,273,258    1
#             ..
# 9,213,048    1
# 9,358,019    1
# 9,797,273    1
# 916,024      1
# 984,812      1
# Length: 190, dtype: int64

# %%
# Analyze largest cities
largest_cities_statistics = urbanization_data['Largest city'].describe()
largest_cities_statistics.to_csv('../Report_materials/largest_cities_statistics.csv')

# %%
largest_cities_statistics
# Out:
# count       189
# unique      188
# top       S����
# freq          2
# Name: Largest city, dtype: object
